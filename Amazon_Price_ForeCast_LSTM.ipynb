# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

# %%
data = pd.read_csv('AMZN.csv')

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume
# 0     1443120000
# 1      294000000
# 2      122136000
# 3      109344000
# 4      377064000
# ...          ...
# 6511    53633400
# 6512    56704300
# 6513    41135700
# 6514    48662500
# 6515    45103000
#
# [6516 rows x 7 columns]

# %%
data = data[['Date', 'Close']]

# %%
data
# Out:
#             Date       Close
# 0     1997-05-15    0.097917
# 1     1997-05-16    0.086458
# 2     1997-05-19    0.085417
# 3     1997-05-20    0.081771
# 4     1997-05-21    0.071354
# ...          ...         ...
# 6511  2023-03-30  102.000000
# 6512  2023-03-31  103.290001
# 6513  2023-04-03  102.410004
# 6514  2023-04-04  103.949997
# 6515  2023-04-05  101.099998
#
# [6516 rows x 2 columns]

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
data['Date'] = pd.to_datetime(data['Date'])
plt.plot(data['Date'], data['Close'])
# Out:
# C:\Users\Faraz\AppData\Local\Temp\ipykernel_4332\3250349648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Date'] = pd.to_datetime(data['Date'])

# %%
from copy import deepcopy as dc

def prepare_dataframe_for_lstm(df, n_steps):
    df = dc(df)

    df.set_index('Date', inplace=True)

    for i in range(1, n_steps+1):
        df[f'Close(t-{i})'] = df['Close'].shift(i)

    df.dropna(inplace=True)

    return df

lookback = 7
shifted_df = prepare_dataframe_for_lstm(data, lookback)
shifted_df
# Out:
#                  Close  Close(t-1)  Close(t-2)  Close(t-3)  Close(t-4)  \
# Date
# 1997-05-27    0.079167    0.075000    0.069792    0.071354    0.081771
# 1997-05-28    0.076563    0.079167    0.075000    0.069792    0.071354
# 1997-05-29    0.075260    0.076563    0.079167    0.075000    0.069792
# 1997-05-30    0.075000    0.075260    0.076563    0.079167    0.075000
# 1997-06-02    0.075521    0.075000    0.075260    0.076563    0.079167
# ...                ...         ...         ...         ...         ...
# 2023-03-30  102.000000  100.250000   97.239998   98.040001   98.129997
# 2023-03-31  103.290001  102.000000  100.250000   97.239998   98.040001
# 2023-04-03  102.410004  103.290001  102.000000  100.250000   97.239998
# 2023-04-04  103.949997  102.410004  103.290001  102.000000  100.250000
# 2023-04-05  101.099998  103.949997  102.410004  103.290001  102.000000
#
#             Close(t-5)  Close(t-6)  Close(t-7)
# Date
# 1997-05-27    0.085417    0.086458    0.097917
# 1997-05-28    0.081771    0.085417    0.086458
# 1997-05-29    0.071354    0.081771    0.085417
# 1997-05-30    0.069792    0.071354    0.081771
# 1997-06-02    0.075000    0.069792    0.071354
# ...                ...         ...         ...
# 2023-03-30   98.709999   98.699997  100.610001
# 2023-03-31   98.129997   98.709999   98.699997
# 2023-04-03   98.040001   98.129997   98.709999
# 2023-04-04   97.239998   98.040001   98.129997
# 2023-04-05  100.250000   97.239998   98.040001
#
# [6509 rows x 8 columns]

# %%
shifted_df_as_np = shifted_df.to_numpy()
shifted_df_as_np
# Out:
# array([[7.91670000e-02, 7.50000000e-02, 6.97920000e-02, ...,
#         8.54170000e-02, 8.64580000e-02, 9.79170000e-02],
#        [7.65630000e-02, 7.91670000e-02, 7.50000000e-02, ...,
#         8.17710000e-02, 8.54170000e-02, 8.64580000e-02],
#        [7.52600000e-02, 7.65630000e-02, 7.91670000e-02, ...,
#         7.13540000e-02, 8.17710000e-02, 8.54170000e-02],
#        ...,
#        [1.02410004e+02, 1.03290001e+02, 1.02000000e+02, ...,
#         9.80400010e+01, 9.81299970e+01, 9.87099990e+01],
#        [1.03949997e+02, 1.02410004e+02, 1.03290001e+02, ...,
#         9.72399980e+01, 9.80400010e+01, 9.81299970e+01],
#        [1.01099998e+02, 1.03949997e+02, 1.02410004e+02, ...,
#         1.00250000e+02, 9.72399980e+01, 9.80400010e+01]])

# %%
from sklearn.preprocessing import MinMaxScaler

scalar = MinMaxScaler(feature_range=(-1, 1))
shifted_df_as_np = scalar.fit_transform(shifted_df_as_np)

shifted_df_as_np
# Out:
# array([[-0.99991063, -0.99995531, -1.        , ..., -0.99983244,
#         -0.99982128, -0.99969839],
#        [-0.99993855, -0.99991063, -0.99994415, ..., -0.99987154,
#         -0.99983244, -0.99982128],
#        [-0.99995253, -0.99993855, -0.99989946, ..., -0.99998325,
#         -0.99987154, -0.99983244],
#        ...,
#        [ 0.09747299,  0.10690997,  0.09308121, ...,  0.0506149 ,
#          0.05158   ,  0.05779984],
#        [ 0.11398769,  0.09747299,  0.10691495, ...,  0.04203581,
#          0.0506149 ,  0.05158   ],
#        [ 0.08342464,  0.11398769,  0.09747802, ...,  0.07431453,
#          0.04203581,  0.0506149 ]])

# %%
x = shifted_df_as_np[:, 1:]
y = shifted_df_as_np[:, 0]

x.shape, y.shape
# Out:
# ((6509, 7), (6509,))

# %%
x = dc(np.flip(x, axis = 1))
x
# Out:
# array([[-0.99969839, -0.99982128, -0.99983244, ..., -0.99998325,
#         -1.        , -0.99995531],
#        [-0.99982128, -0.99983244, -0.99987154, ..., -1.        ,
#         -0.99994415, -0.99991063],
#        [-0.99983244, -0.99987154, -0.99998325, ..., -0.99994415,
#         -0.99989946, -0.99993855],
#        ...,
#        [ 0.05779984,  0.05158   ,  0.0506149 , ...,  0.07431453,
#          0.09308121,  0.10690997],
#        [ 0.05158   ,  0.0506149 ,  0.04203581, ...,  0.09308121,
#          0.10691495,  0.09747299],
#        [ 0.0506149 ,  0.04203581,  0.07431453, ...,  0.10691495,
#          0.09747802,  0.11398769]])

# %%
split_index = int(len(x) * 0.95)
split_index
# Out:
# 6183

# %%
x_train = x[:split_index]
x_test = x[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((6183, 7), (326, 7), (6183,), (326,))

# %%
x_train = x_train.reshape((-1, lookback, 1))
x_test = x_test.reshape((-1, lookback, 1))

y_train = y_train.reshape((-1,1))
y_test = y_test.reshape((-1,1))

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((6183, 7, 1), (326, 7, 1), (6183, 1), (326, 1))

# %%
x_train = torch.tensor(x_train).float()
y_train = torch.tensor(y_train).float()
x_test = torch.tensor(x_test).float()
y_test = torch.tensor(y_test).float()

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([6183, 7, 1]),
#  torch.Size([326, 7, 1]),
#  torch.Size([6183, 1]),
#  torch.Size([326, 1]))

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    def __getitem__(self, i):
        return self.x[i], self.y[i]

train_dataset = TimeSeriesDataset(x_train, y_train)
test_dataset = TimeSeriesDataset(x_test, y_test)

# %%
train_dataset

# %%
from torch.utils.data import DataLoader

batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([16, 7, 1]) torch.Size([16, 1])

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers,
                                batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

model = LSTM(1, 4, 1)
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(1, 4, batch_first=True)
#   (fc): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
def train_one_epoch():
    model.train(True)
    print(f'Epoch: {epoch + 1 }')
    running_loss = 0.0

    for batch_index, batch in enumerate(train_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        output = model(x_batch)
        loss = loss_function(output, y_batch)
        running_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_index % 100 == 99:  # print every 100 batches
            avg_loss_across_batches = running_loss /100
            print('Batch {0}, Loss: {1:.3f}'.format(batch_index+1, 
                                                    avg_loss_across_batches))
            running_loss = 0.0
    print()

# %%
def validate_one_epoch():
    model.train(False)
    running_loss = 0.0

    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        with torch.no_grad():
            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss

        avg_loss_across_batches = running_loss / len(test_loader)

        print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
        print('***************************************************')
        print()

# %%
learning_rate = 0.001
num_epochs = 100
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train_one_epoch()
    validate_one_epoch()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.004
# ***************************************************
#
# Val Loss: 0.004
# ***************************************************
#
# Val Loss: 0.004
# ***************************************************
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.004
# ***************************************************
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.004
# ***************************************************
#
# Val Loss: 0.004
# ***************************************************
#
# Val Loss: 0.004
# ***************************************************
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 31
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 32
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ...
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 91
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 92
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 93
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 94
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 95
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 96
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 97
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 98
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 99
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 100
# Batch 100, Loss: 0.000
# Batch 200, Loss: 0.000
# Batch 300, Loss: 0.000
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.000
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.001
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************
#
# Val Loss: 0.002
# ***************************************************

# %%
with torch.no_grad():
    predicted = model(x_train.to(device)).to('cpu').numpy()

plt.plot(y_train, label='Actual Close')
plt.plot(predicted, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()

# %%
train_predictions = predicted.flatten()

dummies = np.zeros((x_train.shape[0], lookback+1))
dummies[:, 0] = train_predictions
dummies = scalar.inverse_transform(dummies)

train_predictions = dc(dummies[:, 0])
train_predictions
# Out:
# array([  0.28478739,   0.28301991,   0.28204168, ..., 169.57043186,
#        169.02694747, 169.43986043])

# %%
dummies = np.zeros((x_train.shape[0], lookback+1))
dummies[:, 0] = y_train.flatten()
dummies = scalar.inverse_transform(dummies)

new_y_train = dc(dummies[:, 0])
new_y_train
# Out:
# array([7.91646265e-02, 7.65634249e-02, 7.52572660e-02, ...,
#        1.69091505e+02, 1.73315001e+02, 1.68871003e+02])

# %%
plt.plot(new_y_train, label='Actual Close')
plt.plot(train_predictions, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()

# %%
test_predictions = model(x_test.to(device)).detach().cpu().numpy().flatten()
dummies = np.zeros((x_test.shape[0], lookback+1))
dummies[:, 0] = test_predictions
dummies = scalar.inverse_transform(dummies)

test_predictions = dc(dummies[:, 0])
test_predictions
# Out:
# array([168.79496808, 168.49798089, 167.76793254, 167.93688837,
#        168.26356705, 168.4841634 , 168.26961985, 168.39921305,
#        168.19629709, 167.99288646, 167.3977671 , 167.70446989,
#        167.36108905, 166.44422662, 165.53188851, 164.77048123,
#        163.99623468, 164.33652521, 164.46608506, 163.69998672,
#        163.41736728, 162.53893928, 161.28775019, 159.28151231,
#        155.35776644, 152.89606261, 149.96015084, 147.34404791,
#        145.68545396, 145.76164471, 147.5583469 , 149.62872552,
#        150.87914202, 148.70380381, 152.29559078, 155.04023087,
#        157.60762797, 159.1962785 , 159.74641596, 158.78290421,
#        158.91409259, 158.85528765, 159.18069908, 158.45274058,
#        157.38069536, 156.05352117, 153.83521311, 153.87339186,
#        154.54315681, 154.86847375, 154.54762554, 154.61293904,
#        153.66602384, 152.52467994, 149.21636837, 146.20560535,
#        144.91796609, 146.21277533, 146.74404852, 146.1735183 ,
#        147.39951798, 150.24694999, 153.44118109, 156.59609959,
#        158.6312675 , 160.9058182 , 162.29414286, 163.1670183 ,
#         89.09171097,  90.91705417,  93.14780131,  94.44506168,
#         95.14041067,  95.15557323,  96.04402253,  96.57028786,
#         96.62381814,  96.73144564,  97.50408588,  99.00605193,
#         99.79830679, 100.93863078, 102.41420407, 105.91856732,
#        105.82359568, 105.22628642, 104.62873261, 103.70468353,
#        102.34245982, 100.99741348, 100.07715505,  99.9124762 ,
#        100.24387373,  99.644822  ,  98.996831  ,  97.87291737,
#         97.3735089 ,  96.9123014 ,  95.89782722,  95.0732741 ,
#         94.72144491,  93.9346648 ,  93.43672367,  93.74276504,
#         93.67492815,  93.66936447,  93.74720598,  93.32977982,
#         92.69989441,  92.67718947,  93.19624591,  94.02898615,
#         95.74479542,  96.75708526,  97.26599812,  98.57075084,
#         98.99698107,  99.19600078,  99.12918381,  98.85009099,
#         98.47046007,  99.08588881,  99.92202227, 101.0339776 ,
#        101.63562219, 102.56789451])

# %%
dummies = np.zeros((x_test.shape[0], lookback+1))
dummies[:, 0] = y_test.flatten()
dummies = scalar.inverse_transform(dummies)

new_y_test = dc(dummies[:, 0])
new_y_test
# Out:
# array([170.01749949, 167.07899763, 170.41700626, 171.03700377,
#        171.0684961 , 169.66949429, 170.66099675, 169.20100565,
#        168.64449858, 166.71699707, 170.40449492, 167.52200227,
#        164.35699578, 163.25399737, 162.55400179, 161.48599177,
#        165.36199892, 165.20699954, 161.21400501, 162.13799851,
#        158.91749416, 156.29899568, 151.66749509, 142.64300408,
#        144.54400445, 139.98599336, 138.87249844, 139.63749627,
#        143.97799855, 149.57350001, 151.19349835, 150.61250219,
#        138.84550541, 157.63949825, 157.93550165, 161.41349717,
#        161.18949925, 159.003495  , 153.29350176, 155.1670061 ,
#        156.51049894, 158.10049453, 154.6524962 , 152.60149876,
#        150.19749381, 144.82699629, 151.35800212, 153.78849709,
#        153.56300403, 151.14199678, 152.05250627, 147.89849848,
#        145.64100565, 137.45300383, 136.01449488, 139.27900567,
#        146.81750468, 145.52450739, 141.8529947 , 147.36650272,
#        153.10400311, 157.23899657, 161.25050521, 161.49149987,
#        164.8890082 , 163.4080074 , 163.64950785, 164.77349929,
#        168.99049174, 169.31500275, 166.30099379, 162.99749555,
#        163.55999984, 168.34649425, 164.05499516, 158.75599734,
#        157.78449856, 154.4604964 , 151.1219931 , 150.78750525,
#        155.54100108, 151.70649644, 152.78500575, 158.11549591,
#        153.99799942, 148.29600432, 144.35000372, 146.07400567,
#        139.39100462, 138.16700588, 144.59649537, 124.2815027 ,
#        124.50000086, 124.25350088, 125.92849685, 116.40699847,
#        114.77249899, 108.78900163, 108.85900063, 105.37200234,
#        106.93049589, 113.05500005, 110.81050072, 115.36850069,
#        107.11250358, 107.31900035, 107.59100239, 107.55699918,
#        104.09999809, 106.77500184, 111.07749906, 115.14649953,
#        120.20950223, 121.68399725, 125.51100121, 122.34999935,
#        124.79000149, 122.99999961, 121.18000054, 116.15000198,
#        109.65000214, 103.66999806, 102.30999829, 107.6699986 ,
#        103.66000386, 106.22000101, 108.67999989, 108.94999683,
#        112.44000207, 116.45999935, 113.22000127, 107.40000166,
